# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.07478245, 0.68874077, 0.21899134, 0.63707339, 0.46804987,
#        0.46210231, 0.74748502, 0.81357154, 0.19966956, 0.42482124,
#        0.129092  , 0.56233102, 0.36658494, 0.33753236, 0.12743534,
#        0.84769547, 0.0629279 , 0.54890468, 0.38496927, 0.64030496,
#        0.9275867 , 0.22950313, 0.60001442, 0.57648688, 0.09415923,
#        0.72226651, 0.23679765, 0.81936675, 0.41049896, 0.52778867,
#        0.15338538, 0.25625196, 0.77068752, 0.17831912, 0.60003147,
#        0.03155186, 0.30237131, 0.27051602, 0.09840505, 0.59267558,
#        0.76362756, 0.16097211, 0.55170296, 0.44717533, 0.70922921,
#        0.25766279, 0.96597197, 0.46759766, 0.4713655 , 0.10396075])

# %%
y
# Out:
# array([0.90599846, 0.9648983 , 0.83714936, 0.39473388, 0.21461495,
#        0.680971  , 0.06573898, 0.25870635, 0.36311836, 0.69547698,
#        0.99757602, 0.23021455, 0.36077487, 0.61938064, 0.29425395,
#        0.34382931, 0.83014109, 0.07255703, 0.79798568, 0.49975491,
#        0.80158559, 0.96036544, 0.84666607, 0.14778973, 0.98661257,
#        0.42370797, 0.10055562, 0.43669445, 0.39881885, 0.45607635,
#        0.85331825, 0.50279051, 0.114804  , 0.19798908, 0.53225104,
#        0.17041915, 0.73162913, 0.1857235 , 0.13243688, 0.17744451,
#        0.77145407, 0.83005987, 0.77459094, 0.89376056, 0.75435758,
#        0.50493286, 0.76152772, 0.99842383, 0.20429512, 0.61215103])

# %%
plt.scatter(x,y)

# %%
plt.figure(figsize = (8,8))
plt.scatter(x,y, c='#223BDC', alpha=.9, marker='x')
plt.xlabel('This is my x_axis')
plt.ylabel('This is my y_axis')
plt.title('This is my x versus y')
plt.grid()

# %%
x = np.linspace(1,10, 100)
y = np.sin(x)

# %%
x
# Out:
# array([ 1.        ,  1.09090909,  1.18181818,  1.27272727,  1.36363636,
#         1.45454545,  1.54545455,  1.63636364,  1.72727273,  1.81818182,
#         1.90909091,  2.        ,  2.09090909,  2.18181818,  2.27272727,
#         2.36363636,  2.45454545,  2.54545455,  2.63636364,  2.72727273,
#         2.81818182,  2.90909091,  3.        ,  3.09090909,  3.18181818,
#         3.27272727,  3.36363636,  3.45454545,  3.54545455,  3.63636364,
#         3.72727273,  3.81818182,  3.90909091,  4.        ,  4.09090909,
#         4.18181818,  4.27272727,  4.36363636,  4.45454545,  4.54545455,
#         4.63636364,  4.72727273,  4.81818182,  4.90909091,  5.        ,
#         5.09090909,  5.18181818,  5.27272727,  5.36363636,  5.45454545,
#         5.54545455,  5.63636364,  5.72727273,  5.81818182,  5.90909091,
#         6.        ,  6.09090909,  6.18181818,  6.27272727,  6.36363636,
#         6.45454545,  6.54545455,  6.63636364,  6.72727273,  6.81818182,
# ...

# %%
y
# Out:
# array([ 0.84147098,  0.88704699,  0.92529707,  0.95590534,  0.978619  ,
#         0.99325047,  0.99967891,  0.99785123,  0.98778253,  0.96955595,
#         0.94332203,  0.90929743,  0.86776314,  0.8190622 ,  0.76359681,
#         0.70182505,  0.63425707,  0.56145091,  0.48400786,  0.40256749,
#         0.31780241,  0.23041267,  0.14112001,  0.05066187, -0.04021468,
#        -0.1307591 , -0.22022362, -0.30786935, -0.39297247, -0.47483011,
#        -0.55276624, -0.6261372 , -0.69433703, -0.7568025 , -0.8130177 ,
#        -0.86251837, -0.9048957 , -0.93979971, -0.96694212, -0.98609877,
#        -0.99711147, -0.99988924, -0.99440916, -0.98071647, -0.95892427,
#        -0.92921254, -0.89182665, -0.84707537, -0.79532828, -0.73701276,
#        -0.67261042, -0.60265314, -0.52771868, -0.44842592, -0.36542971,
#        -0.2794155 , -0.19109366, -0.10119362, -0.01045784,  0.0803643 ,
#         0.17052273,  0.25927286,  0.34588171,  0.429634  ,  0.50983804,
# ...

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.figure(figsize=(8,3))
plt.plot(x,y, '--r')
plt.xlabel('This is my x data')
plt.ylabel('This is my y data')
plt.title('This is my sin wave graph')
plt.grid()

# %%
x = ['a', 'b', 'c', 'd', 'e']

y = np.random.rand(5)

# %%
x
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
y
# Out:
# array([0.98337546, 0.16528184, 0.42203987, 0.40929403, 0.02633609])

# %%
plt.figure(figsize=(5,3))
plt.bar(x,y, color= '#7E10D5')
plt.xlabel('Representinf my cat data')
plt.ylabel('Representinf my num data')
plt.title('This is my bar plot')
plt.grid()

# %%
plt.figure(figsize=(5,3))
plt.barh(x,y, color= '#7E10D5')
plt.xlabel('Representinf my cat data')
plt.ylabel('Representinf my num data')
plt.title('This is my bar plot')
plt.grid()

# %%
x = [3,4,5,6,7,8]
y = [4,5,6,7,8,9]

# %%
plt.figure(figsize=(6,2))
plt.plot(x,y)

# %%
plt.figure(figsize=(6,2))
plt.scatter(x,y)

# %%
data = [1,2,3,4,5,6,5,1,1,6,6,7,7,8,8,8,8,8]

# %%
plt.figure(figsize=(6,3))
plt.hist(data, color='#700EBB')     # Represents the frequencies of the data points
plt.xlabel('Representing unique values')
plt.ylabel('Representing frequencies')
plt.title('Histogram plot Example')
plt.grid()

plt.savefig("histogram_test.png")

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z, c='r', alpha=.8)
plt.xlabel('my x axis')
plt.ylabel('my y axis')
plt.title('3D Graph')
plt.show()

plt.savefig('3D Graph.png')

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.figure(figsize = (10,8))
sns.scatterplot(x=iris['sepal_length'], y=iris['sepal_width'])
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x=iris['sepal_length'], y=iris['petal_length'])
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.distplot(iris['sepal_length'])
# Out:
# C:\Users\sodiq\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.displot(iris['sepal_length'])

# %%
sns.histplot(iris['sepal_length'])
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x = tips['total_bill'], y = tips['tip'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x = tips['total_bill'], y = tips['tip'], data=tips, hue='smoker')

# %%
sns.relplot(x = tips['total_bill'], y = tips['tip'], data=tips, hue='size')

# %%
sns.relplot(x = tips['total_bill'], y = tips['tip'], data=tips, style='size')

# %%
sns.relplot(x = tips['total_bill'], y = tips['tip'], data=tips, style='size', hue='time')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x='day', y='total_bill', data=tips)

# %%
sns.catplot(x='smoker', y='tip', data=tips)

# %%
sns.jointplot(x=tips['total_bill'], y=tips['tip'])

# %%
sns.pairplot(tips)

# %%
sns.pairplot(iris)

# %% [markdown]
# ## Plotly

# %%
import numpy as np
import plotly.graph_objects as go

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=[1,2,3,4,5,3], y=[3,4,5,5,6,7], mode='markers'))

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=[1,2,3,4,5,3], y=[3,4,5,5,6,7], mode='lines'))

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

fig = go.Figure()
fig.add_trace(go.Scatter(x=[1,2,3,4,5,3], y=[3,4,5,5,6,7], mode='markers'))

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=tips['total_bill'], y=tips['tip'], mode='markers'))

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=tips['total_bill'], y=tips['tip'], mode='lines'))

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x=[1,2,3,4,5,3], y=[3,4,5,5,6,7]))

# %%
fig = go.Figure()
fig.add_trace(go.Histogram(x=tips['smoker'] ))

# %%
fig = go.Figure()
fig.add_trace(go.Histogram(x=tips['size']))

# %%
fig = go.Figure()
fig.add_trace(go.Histogram(x=tips['total_bill'] ))

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=tips['total_bill'], y=tips['tip'], mode='markers', marker_size=10*tips['size'], ))

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig = go.Figure()
fig.add_trace(go.Scatter3d(x=tips['total_bill'], y=tips['tip'], mode='markers', z=10*tips['size'], ))

# %%
fig = go.Figure()
fig.add_trace(go.Scatter3d(x=tips['total_bill'], y=tips['tip'], mode='lines', z=10*tips['size'], ))

# %%
fig = go.Figure()
fig.add_trace(go.Scatter3d(x=[1,2,3,4,2], y=[3,4,5,6,6], mode='lines', z=[3,4,5,6,7], ))

# %%
fig = go.Figure()
fig.add_trace(go.Scatter3d(x=[1,2,3,4,2], y=[3,4,5,6,6], mode='markers', z=[3,4,5,6,7], ))

# %% [markdown]
# ## BoKEh

# %%
# !pip install bokeh

# %%
pip install --upgrade pip
# Out:
# ...
#   Using cached pip-23.0.1-py3-none-any.whl (2.1 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.2.2
#     Uninstalling pip-22.2.2:
#       Successfully uninstalled pip-22.2.2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1001">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file('test.html')

p = figure(title='test flower')
p.xaxis.axis_label = 'petal_length'
p.yaxis.axis_label = 'petal_width'
p.circle(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="83fab224-6216-48a2-8449-c8484f373daa" data-root-id="p1002" style="display: contents;"></div>

# %%
output_file('test.html')

p = figure(title='test flower')
p.xaxis.axis_label = 'petal_length'
p.yaxis.axis_label = 'petal_width'
p.line(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="0ca9ef0f-0963-493e-9332-569cd102fb67" data-root-id="p1193" style="display: contents;"></div>
